# %% [markdown]
# # Step 6 — Custom NER Model 1 (spaCy, blank English pipeline)
#
# Training source: `220_docs_with_overlap.json` — 220 human-annotated sentences.
# Labels (8): Rating, Amenity, Location, Restaurant_Name, Price, Hours, Dish, Cuisine.
# Split: 80/20, approximately stratified by rarest entity per sentence.
# Eval: seqeval entity-level classification report + per-entity P/R/F1 + confusion matrix.

# %%
import json, random, warnings
from pathlib import Path
from collections import Counter, defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import spacy
from spacy.training import Example
from spacy.util import minibatch, compounding

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

warnings.filterwarnings("ignore")
random.seed(42); np.random.seed(42)

# %%
HPARAMS = {
    "model_base": "blank:en",
    "labels": ["Rating", "Amenity", "Location", "Restaurant_Name",
               "Price", "Hours", "Dish", "Cuisine"],
    "test_size": 0.20,
    "random_state": 42,
    "n_epochs": 30,
    "dropout": 0.35,
    "batch_start": 4.0,
    "batch_stop": 32.0,
    "batch_compound": 1.001,
    "optimizer": "spacy-default (Adam)",
}
HPARAMS
# Out:
# {'model_base': 'blank:en',
#  'labels': ['Rating',
#   'Amenity',
#   'Location',
#   'Restaurant_Name',
#   'Price',
#   'Hours',
#   'Dish',
#   'Cuisine'],
#  'test_size': 0.2,
#  'random_state': 42,
#  'n_epochs': 30,
#  'dropout': 0.35,
#  'batch_start': 4.0,
#  'batch_stop': 32.0,
#  'batch_compound': 1.001,
#  'optimizer': 'spacy-default (Adam)'}

# %%
with open("220_docs_with_overlap.json", "r", encoding="utf-8") as f:
    tasks = json.load(f)

print("Total tasks:", len(tasks))
# Out:
# Total tasks: 220

# %%
def pick_gold_annotation(task):
    """Use reviewed/accepted annotation if present; else first."""
    anns = task.get("annotations", [])
    if not anns:
        return None
    for a in anns:
        if a.get("state") == "ACCEPTED" or a.get("reviews"):
            return a
    return anns[0]

docs_raw = []
for t in tasks:
    ann = pick_gold_annotation(t)
    if ann is None:
        continue
    text = t["data"]["text"]
    ents = []
    for r in ann.get("result", []):
        if r.get("type") != "labels":
            continue
        v = r["value"]
        if v.get("labels"):
            ents.append((v["start"], v["end"], v["labels"][0]))
    docs_raw.append((text, ents))

print("Docs prepared:", len(docs_raw))
print("Example:", docs_raw[0])
# Out:
# Docs prepared: 220
# Example: ('can you find me the closed burger king', [(20, 26, 'Hours'), (27, 38, 'Restaurant_Name')])

# %%
nlp_blank = spacy.blank("en")

def to_spacy_example(text, ents):
    doc = nlp_blank.make_doc(text)
    spans = []
    for start, end, label in ents:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is not None:
            spans.append(span)
    doc.ents = spacy.util.filter_spans(spans)
    return doc

spacy_docs = [to_spacy_example(t, e) for t, e in docs_raw]
print("spaCy docs built:", len(spacy_docs))
print("Entities in first doc:", [(e.text, e.label_) for e in spacy_docs[0].ents])
# Out:
# spaCy docs built: 220
# Entities in first doc: [('closed', 'Hours'), ('burger king', 'Restaurant_Name')]

# %%
label_priority = {lab: i for i, lab in enumerate(
    # rarest first → used as stratum
    ["Hours", "Price", "Rating", "Dish", "Cuisine",
     "Restaurant_Name", "Amenity", "Location"]
)}

def rarest_label(doc):
    labs = [e.label_ for e in doc.ents]
    if not labs:
        return "NONE"
    return sorted(labs, key=lambda x: label_priority.get(x, 99))[0]

strata = [rarest_label(d) for d in spacy_docs]
print("Stratum distribution:", Counter(strata))

# Drop strata with <2 docs for stratify (sklearn requirement)
strata_counts = Counter(strata)
safe_strata = [s if strata_counts[s] >= 2 else "NONE" for s in strata]

train_docs, test_docs = train_test_split(
    spacy_docs,
    test_size=HPARAMS["test_size"],
    random_state=HPARAMS["random_state"],
    stratify=safe_strata,
)
print(f"Train: {len(train_docs)} | Test: {len(test_docs)}")
# Out:
# Stratum distribution: Counter({'Restaurant_Name': 46, 'Cuisine': 40, 'Amenity': 33, 'Rating': 29, 'Dish': 24, 'Price': 17, 'Hours': 15, 'Location': 10, 'NONE': 6})
# Train: 176 | Test: 44

# %%
nlp = spacy.blank("en")
ner = nlp.add_pipe("ner")

for label in HPARAMS["labels"]:
    ner.add_label(label)

print("Pipeline:", nlp.pipe_names)
print("NER labels:", ner.labels)
# Out:
# Pipeline: ['ner']
# NER labels: ('Amenity', 'Cuisine', 'Dish', 'Hours', 'Location', 'Price', 'Rating', 'Restaurant_Name')

# %%
optimizer = nlp.initialize(lambda: [Example(nlp.make_doc(d.text), d) for d in train_docs])

loss_history = []
for epoch in range(HPARAMS["n_epochs"]):
    random.shuffle(train_docs)
    losses = {}
    batches = minibatch(
        train_docs,
        size=compounding(HPARAMS["batch_start"],
                         HPARAMS["batch_stop"],
                         HPARAMS["batch_compound"])
    )
    for batch in batches:
        examples = [Example(nlp.make_doc(d.text), d) for d in batch]
        nlp.update(examples, drop=HPARAMS["dropout"], losses=losses, sgd=optimizer)
    loss_history.append(losses.get("ner", 0.0))
    print(f"Epoch {epoch+1:02d} | NER loss: {losses.get('ner', 0.0):.3f}")
# Out:
# Epoch 01 | NER loss: 876.352
# Epoch 02 | NER loss: 476.054
# Epoch 03 | NER loss: 408.214
# Epoch 04 | NER loss: 392.524
# Epoch 05 | NER loss: 351.313
# Epoch 06 | NER loss: 322.507
# Epoch 07 | NER loss: 301.323
# Epoch 08 | NER loss: 280.484
# Epoch 09 | NER loss: 285.243
# Epoch 10 | NER loss: 241.067
# Epoch 11 | NER loss: 216.184
# Epoch 12 | NER loss: 185.090
# Epoch 13 | NER loss: 203.193
# Epoch 14 | NER loss: 175.468
# Epoch 15 | NER loss: 170.926
# Epoch 16 | NER loss: 149.580
# Epoch 17 | NER loss: 136.635
# Epoch 18 | NER loss: 102.788
# Epoch 19 | NER loss: 109.870
# Epoch 20 | NER loss: 99.702
# Epoch 21 | NER loss: 96.716
# Epoch 22 | NER loss: 91.715
# Epoch 23 | NER loss: 96.143
# Epoch 24 | NER loss: 91.433
# Epoch 25 | NER loss: 79.414
# Epoch 26 | NER loss: 63.973
# Epoch 27 | NER loss: 72.106
# Epoch 28 | NER loss: 66.321
# Epoch 29 | NER loss: 64.615
# Epoch 30 | NER loss: 80.575

# %%
plt.figure(figsize=(7,4))
plt.plot(range(1, len(loss_history)+1), loss_history, marker="o")
plt.xlabel("Epoch"); plt.ylabel("NER loss")
plt.title("Custom NER Model 1 — Training Loss")
plt.grid(True, alpha=0.3); plt.tight_layout()
plt.show()

# %%
def doc_to_iob(doc):
    tags = ["O"] * len(doc)
    for ent in doc.ents:
        tags[ent.start] = f"B-{ent.label_}"
        for i in range(ent.start + 1, ent.end):
            tags[i] = f"I-{ent.label_}"
    return tags

def aligned_iob(gold_doc, pred_doc):
    """Tokenize pred with the same whitespace as gold for apples-to-apples eval."""
    # Use gold's tokenization (blank spaCy whitespace tokenizer matches input)
    pred = nlp(gold_doc.text)
    return doc_to_iob(gold_doc), doc_to_iob(pred)

# %%
#%pip install seqeval

# %%
from seqeval.metrics import classification_report as seq_report
from seqeval.metrics import f1_score as seq_f1

# %%
y_true, y_pred = [], []
for gold in test_docs:
    t, p = aligned_iob(gold, None)
    y_true.append(t); y_pred.append(p)

print("Entity-level classification report (seqeval):")
print(seq_report(y_true, y_pred, digits=4))
print(f"Overall entity-level F1: {seq_f1(y_true, y_pred):.4f}")
# Out:
# Entity-level classification report (seqeval):
#                  precision    recall  f1-score   support
#
#         Amenity     0.7826    0.6429    0.7059        28
#         Cuisine     0.6250    0.7692    0.6897        13
#            Dish     0.4000    0.2857    0.3333         7
#           Hours     0.0000    0.0000    0.0000         3
#        Location     0.6667    0.5833    0.6222        24
#           Price     1.0000    0.6667    0.8000         3
#          Rating     0.5556    0.7143    0.6250         7
# Restaurant_Name     0.4286    0.6000    0.5000        10
#
#       micro avg     0.6196    0.6000    0.6096        95
#       macro avg     0.5573    0.5328    0.5345        95
#    weighted avg     0.6317    0.6000    0.6081        95
#
# Overall entity-level F1: 0.6096

# %%
from seqeval.metrics import precision_score, recall_score

rows = []
for lab in HPARAMS["labels"]:
    # per-entity via seqeval by masking all others to O
    def keep_only(sents, keep):
        return [[t if t.endswith(keep) or t == "O" else "O" for t in s] for s in sents]
    yt = keep_only(y_true, lab)
    yp = keep_only(y_pred, lab)
    rows.append({
        "entity": lab,
        "precision": precision_score(yt, yp),
        "recall":    recall_score(yt, yp),
        "f1":        seq_f1(yt, yp),
    })

per_entity_df = pd.DataFrame(rows).sort_values("f1", ascending=False).reset_index(drop=True)
per_entity_df
# Out:
#             entity  precision    recall        f1
# 0            Price   1.000000  0.666667  0.800000
# 1          Amenity   0.782609  0.642857  0.705882
# 2          Cuisine   0.625000  0.769231  0.689655
# 3           Rating   0.555556  0.714286  0.625000
# 4         Location   0.666667  0.583333  0.622222
# 5  Restaurant_Name   0.428571  0.600000  0.500000
# 6             Dish   0.400000  0.285714  0.333333
# 7            Hours   0.000000  0.000000  0.000000

# %%
def collapse_bio(tag):
    return tag[2:] if tag.startswith(("B-", "I-")) else tag

y_true_flat = [collapse_bio(t) for sent in y_true for t in sent]
y_pred_flat = [collapse_bio(t) for sent in y_pred for t in sent]
labels_cm   = sorted(set(y_true_flat + y_pred_flat) - {"O"})

fig, ax = plt.subplots(figsize=(8,6))
cm = confusion_matrix(y_true_flat, y_pred_flat, labels=labels_cm)
ConfusionMatrixDisplay(cm, display_labels=labels_cm).plot(
    ax=ax, cmap="Blues", values_format="d")
ax.set_title("Custom NER Model 1 — Entity Type Confusion (excluding O)")
plt.xticks(rotation=45, ha="right"); plt.tight_layout(); plt.show()

# %%
all_labels = ["O"] + labels_cm
fig, ax = plt.subplots(figsize=(10,8))
cm_full = confusion_matrix(y_true_flat, y_pred_flat, labels=all_labels)
ConfusionMatrixDisplay(cm_full, display_labels=all_labels).plot(
    ax=ax, cmap="Blues", values_format="d")
ax.set_title("Custom NER Model 1 — Entity Confusion (with O)")
plt.xticks(rotation=45, ha="right"); plt.tight_layout(); plt.show()

# %%
def classify_errors(y_true_sents, y_pred_sents):
    counts = Counter()
    for yt, yp in zip(y_true_sents, y_pred_sents):
        for a, b in zip(yt, yp):
            if a == b:
                continue
            if a == "O" and b != "O":
                counts["false_positive"] += 1
            elif a != "O" and b == "O":
                counts["false_negative"] += 1
            elif collapse_bio(a) != collapse_bio(b):
                counts["type_mismatch"] += 1
            else:
                counts["boundary_error"] += 1  # same type, different B/I
    return counts

err = classify_errors(y_true, y_pred)
pd.Series(err).rename("count").to_frame()
# Out:
#                 count
# type_mismatch      29
# false_positive     28
# false_negative     30
# boundary_error      6

# %% [markdown]
# ## Custom NER Model 1 — summary
#
# - Training docs: 176 | Test docs: 44
# - Epochs: 30 | Dropout: 0.35 | Batch compounding: 4 → 32 (×1.001)
# - Overall entity-level F1 (seqeval): **0.6096**
# - Per-entity F1 leaders/laggards: see `per_entity_df`
# - Dominant error category: **FP: 28 / FN: 30 / type: 29 / boundary: 6**
# - Weakest entity types: **Restuarant_Name (0.50000), Dish (0.3333), Hours (0.0000)**

# %% [markdown]
# # Step 7 — Batch 3 Pre-Annotation Generation (for Human Correction)
#
# Goal: run Model 1 on ~100 unseen docs from `dataset_valid.json` (disjoint from training),
# prioritizing candidates likely to contain Dish/Hours (our weakest types).
# Export as Label Studio JSON with `predictions` field so reviewers see editable suggestions.

# %%
import json, random
from pathlib import Path
import spacy

random.seed(42)

# %%
# Option A: re-use `nlp` from the Model 1 notebook (same kernel)
# Option B: load from a saved path — see note at bottom
try:
    nlp
    print("Using in-memory Model 1:", nlp.pipe_names)
except NameError:
    nlp = spacy.load("/path/to/ner_model1_output")  # <- edit if needed
    print("Loaded Model 1 from disk:", nlp.pipe_names)
# Out:
# Using in-memory Model 1: ['ner']

# %%
valid_path = Path("../data/raw/dataset_valid.json")  # adjust if you run from a different cwd

candidates = []
with open(valid_path, "r", encoding="utf-8") as f:
    for line in f:
        obj = json.loads(line)
        text = " ".join(obj["tokens"])
        candidates.append(text)

print("Candidate pool size:", len(candidates))
print("Example:", candidates[0])
# Out:
# Candidate pool size: 760
# Example: 2 start restaurants with inside dining

# %%
# Light, defensible keyword triggers (lowercase, word-level match)
DISH_TRIGGERS = {
    "burger","burgers","pizza","pasta","taco","tacos","burrito","sushi",
    "sandwich","salad","steak","soup","ramen","noodle","noodles","wings",
    "bbq","barbecue","pancake","pancakes","waffle","waffles","fries",
    "dumpling","dumplings","curry","kebab","fried","grilled","chicken",
    "beef","pork","shrimp","lobster","tofu","dish","dishes","entree",
    "appetizer","dessert","ice cream",
}
HOURS_TRIGGERS = {
    "open","opens","closed","close","closes","hours","24","24/7",
    "late","night","early","morning","afternoon","evening","midnight",
    "noon","breakfast","lunch","brunch","dinner","am","pm","weekend",
    "weekday","weekdays","weekends",
}

def has_trigger(text, triggers):
    toks = text.lower().split()
    return any(t in triggers for t in toks)

prioritized = [t for t in candidates if has_trigger(t, DISH_TRIGGERS | HOURS_TRIGGERS)]
print("Prioritized (Dish or Hours trigger):", len(prioritized))
# Out:
# Prioritized (Dish or Hours trigger): 232

# %%
TARGET_SIZE = 100
random.shuffle(prioritized)

batch = prioritized[:TARGET_SIZE]

if len(batch) < TARGET_SIZE:
    remaining = [t for t in candidates if t not in set(batch)]
    random.shuffle(remaining)
    batch += remaining[:TARGET_SIZE - len(batch)]

print("Batch 3 size:", len(batch))
print("Preview:")
for t in batch[:5]: print(" -", t)
# Out:
# Batch 3 size: 100
# Preview:
#  - at what time does dennys open
#  - are there any restaurants nearby that are open late
#  - any beef cuisine restaurants with brewpub and great prices
#  - are there any waterfront dining spots that is open before 12 a
#  - are there any diners open before 5 am that allow smoking

# %%
def export_label_studio_json(texts, nlp_model, output_file):
    """
    Pre-annotated tasks with `predictions` field (editable in Label Studio).
    """
    tasks = []
    for text in texts:
        doc = nlp_model(text)
        results = []
        for ent in doc.ents:
            results.append({
                "from_name": "label",
                "to_name": "text",
                "type": "labels",
                "value": {
                    "start": ent.start_char,
                    "end": ent.end_char,
                    "text": ent.text,
                    "labels": [ent.label_],
                },
            })
        tasks.append({
            "data": {"text": text},
            "predictions": [{"result": results}] if results else [],
        })

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(tasks, f, indent=2)
    print(f"Wrote {len(tasks)} tasks to {output_file}")

# %%
from pathlib import Path
out_path = "batch3_preannotations.json"   # outside the repo
export_label_studio_json(batch, nlp, str(out_path))

# Quick sanity check
with open(out_path) as f:
    preview = json.load(f)
print("Tasks written:", len(preview))
print("First task preview:")
print(json.dumps(preview[0], indent=2)[:800])
# Out:
# Wrote 100 tasks to batch3_preannotations.json
# Tasks written: 100
# First task preview:
# {
#   "data": {
#     "text": "at what time does dennys open"
#   },
#   "predictions": [
#     {
#       "result": [
#         {
#           "from_name": "label",
#           "to_name": "text",
#           "type": "labels",
#           "value": {
#             "start": 8,
#             "end": 17,
#             "text": "time does",
#             "labels": [
#               "Amenity"
#             ]
#           }
#         },
#         {
#           "from_name": "label",
#           "to_name": "text",
#           "type": "labels",
#           "value": {
#             "start": 18,
#             "end": 24,
#             "text": "dennys",
#             "labels": [
#               "Restaurant_Name"
#             ]
#           }
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# **Next step (manual):** upload `~/batch3_preannotations.json` into Label Studio,
# review + correct predictions (focus on Dish and Hours), then export the corrected
# tasks as Label Studio JSON. Save the corrected export as `batch3_corrected.json`
# and point Model 2 at it.

# %% [markdown]
# # Step 7 — Custom NER Model 2 (Expanded Data)
#
# Training source: Model 1 training pool + corrected Batch 3 (pre-annotated by Model 1, human-reviewed).
# Test set: frozen from Model 1 (same `random_state=42`, same stratify rule).
# Labels: Rating, Amenity, Location, Restaurant_Name, Price, Hours, Dish, Cuisine.

# %%
import json, random
from pathlib import Path
from collections import Counter, defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import spacy
from spacy.training import Example
from spacy.util import minibatch, compounding, filter_spans, fix_random_seed
from spacy.scorer import Scorer

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from seqeval.metrics import classification_report as seq_report
from seqeval.metrics import f1_score as seq_f1
from seqeval.metrics import precision_score as seq_p
from seqeval.metrics import recall_score as seq_r

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
fix_random_seed(SEED)
 #seeds pinned as suggested by AI to maintain consistency in different runs, after experiencing changes from restarting kernels
# Out:
# Seeds pinned to 42

# %%
HPARAMS_M2 = {
    "model_base": "blank:en",
    "labels": ["Rating", "Amenity", "Location", "Restaurant_Name",
               "Price", "Hours", "Dish", "Cuisine"],
    "test_size": 0.20,
    "random_state": 42,
    "n_epochs": 30,            # matches Model 1 for fair comparison
    "dropout": 0.25,           # slight reduction from Model 1's 0.35
    "batch_start": 4.0,
    "batch_stop": 32.0,
    "batch_compound": 1.001,
    "optimizer": "spacy-default (Adam)",
    "training_source": "220 base + 100 Batch 3 (fresh 80/20 stratified split)",
}
HPARAMS_M2
# Out:
# {'model_base': 'blank:en',
#  'labels': ['Rating',
#   'Amenity',
#   'Location',
#   'Restaurant_Name',
#   'Price',
#   'Hours',
#   'Dish',
#   'Cuisine'],
#  'test_size': 0.2,
#  'random_state': 42,
#  'n_epochs': 30,
#  'dropout': 0.25,
#  'batch_start': 4.0,
#  'batch_stop': 32.0,
#  'batch_compound': 1.001,
#  'optimizer': 'spacy-default (Adam)',
#  'training_source': '220 base + 100 Batch 3 (fresh 80/20 stratified split)'}

# %%
def pick_gold_annotation(task):
    anns = task.get("annotations", [])
    if not anns: return None
    for a in anns:
        if a.get("state") == "ACCEPTED" or a.get("reviews"):
            return a
    return anns[0]

def ls_task_to_spans(task):
    ann = pick_gold_annotation(task)
    if ann is None: return None
    text = task["data"]["text"]
    ents = []
    for r in ann.get("result", []):
        if r.get("type") != "labels": continue
        v = r["value"]
        if v.get("labels"):
            ents.append((v["start"], v["end"], v["labels"][0]))
    return text, ents

with open("220_docs_with_overlap.json", "r", encoding="utf-8") as f:
    tasks = json.load(f)

base_raw = [x for x in (ls_task_to_spans(t) for t in tasks) if x is not None]
print("Base pool (Model 1 source):", len(base_raw))
# Out:
# Base pool (Model 1 source): 220

# %%
def pick_gold_annotation(task):
    anns = task.get("annotations", [])
    if not anns: return None
    for a in anns:
        if a.get("state") == "ACCEPTED" or a.get("reviews"):
            return a
    return anns[0]

def ls_task_to_spans(task):
    ann = pick_gold_annotation(task)
    if ann is None: return None
    text = task["data"]["text"]
    ents = []
    for r in ann.get("result", []):
        if r.get("type") != "labels": continue
        v = r["value"]
        if v.get("labels"):
            ents.append((v["start"], v["end"], v["labels"][0]))
    return text, ents

with open("220_docs_with_overlap.json", "r", encoding="utf-8") as f:
    tasks = json.load(f)

base_raw = [x for x in (ls_task_to_spans(t) for t in tasks) if x is not None]
print("Base pool (Model 1 source):", len(base_raw))
# Out:
# Base pool (Model 1 source): 220

# %%
BATCH3_PATH = "batch3_corrected.json"

with open(BATCH3_PATH, "r", encoding="utf-8") as f:
    batch3_tasks = json.load(f)

batch3_raw = [x for x in (ls_task_to_spans(t) for t in batch3_tasks) if x is not None]
print("Batch 3 corrected docs:", len(batch3_raw))
# Out:
# Batch 3 corrected docs: 100

# %%
nlp_blank = spacy.blank("en")

def to_spacy_doc(text, ents):
    doc = nlp_blank.make_doc(text)
    spans = []
    for start, end, label in ents:
        s = doc.char_span(start, end, label=label, alignment_mode="contract")
        if s is not None: spans.append(s)
    doc.ents = filter_spans(spans)
    return doc

base_docs   = [to_spacy_doc(t, e) for t, e in base_raw]
batch3_docs = [to_spacy_doc(t, e) for t, e in batch3_raw]
print("Base docs:", len(base_docs), "| Batch 3 docs:", len(batch3_docs))
# Out:
# Base docs: 220 | Batch 3 docs: 100

# %%
all_docs_m2 = base_docs + batch3_docs
print(f"Expanded pool: {len(all_docs_m2)} docs "
      f"(base={len(base_docs)} + batch3={len(batch3_docs)})")

label_priority = {lab: i for i, lab in enumerate(
    ["Hours","Price","Rating","Dish","Cuisine",
     "Restaurant_Name","Amenity","Location"]
)}

def rarest_label(doc):
    labs = [e.label_ for e in doc.ents]
    return sorted(labs, key=lambda x: label_priority.get(x, 99))[0] if labs else "NONE"

strata = [rarest_label(d) for d in all_docs_m2]
sc = Counter(strata)
safe_strata = [s if sc[s] >= 2 else "NONE" for s in strata]

train_docs_m2, test_docs_m2 = train_test_split(
    all_docs_m2,
    test_size=HPARAMS_M2["test_size"],
    random_state=HPARAMS_M2["random_state"],
    stratify=safe_strata,
)
print(f"Model 2 fresh split -> train: {len(train_docs_m2)} | test: {len(test_docs_m2)}")
# Out:
# Expanded pool: 320 docs (base=220 + batch3=100)
# Model 2 fresh split -> train: 256 | test: 64

# %%
# Re-pin seeds immediately before training for determinism
random.seed(SEED); np.random.seed(SEED); fix_random_seed(SEED)

nlp2 = spacy.blank("en")
ner2 = nlp2.add_pipe("ner")
for lab in HPARAMS_M2["labels"]:
    ner2.add_label(lab)
print("Model 2 pipe:", nlp2.pipe_names, "| labels:", ner2.labels)
# Out:
# Model 2 pipe: ['ner'] | labels: ('Amenity', 'Cuisine', 'Dish', 'Hours', 'Location', 'Price', 'Rating', 'Restaurant_Name')

# %%
optimizer = nlp2.initialize(
    lambda: [Example(nlp2.make_doc(d.text), d) for d in train_docs_m2]
)

# Track the absolute-best epoch across the full run
best_loss  = float("inf")
best_epoch = -1
best_bytes = None           # snapshot of best model weights

loss_history_m2 = []
for epoch in range(HPARAMS_M2["n_epochs"]):
    random.shuffle(train_docs_m2)
    losses = {}
    batches = minibatch(
        train_docs_m2,
        size=compounding(HPARAMS_M2["batch_start"],
                         HPARAMS_M2["batch_stop"],
                         HPARAMS_M2["batch_compound"]),
    )
    for batch in batches:
        examples = [Example(nlp2.make_doc(d.text), d) for d in batch]
        nlp2.update(examples, drop=HPARAMS_M2["dropout"], losses=losses, sgd=optimizer)

    ep_loss = losses.get("ner", 0.0)
    loss_history_m2.append(ep_loss)

    improved = ep_loss < best_loss
    if improved:
        best_loss  = ep_loss
        best_epoch = epoch + 1
        best_bytes = nlp2.to_bytes()   # snapshot best weights

    flag = " *" if improved else ""
    print(f"Epoch {epoch+1:02d} | NER loss: {ep_loss:.3f}{flag}")

# Always finish the full run, then restore the absolute-best weights
nlp2.from_bytes(best_bytes)

print(f"\nFinished all {HPARAMS_M2['n_epochs']} epochs.")
print(f"Best epoch: {best_epoch} | Best NER loss: {best_loss:.3f}")
print(f"Final-epoch loss: {loss_history_m2[-1]:.3f}")
print(f"Restored weights from epoch {best_epoch}.")
# Out:
# Epoch 01 | NER loss: 1071.131 *
# Epoch 02 | NER loss: 655.695 *
# Epoch 03 | NER loss: 542.525 *
# Epoch 04 | NER loss: 438.505 *
# Epoch 05 | NER loss: 366.461 *
# Epoch 06 | NER loss: 308.367 *
# Epoch 07 | NER loss: 310.328
# Epoch 08 | NER loss: 240.890 *
# Epoch 09 | NER loss: 192.904 *
# Epoch 10 | NER loss: 183.573 *
# Epoch 11 | NER loss: 140.206 *
# Epoch 12 | NER loss: 148.794
# Epoch 13 | NER loss: 159.000
# Epoch 14 | NER loss: 96.363 *
# Epoch 15 | NER loss: 97.525
# Epoch 16 | NER loss: 112.616
# Epoch 17 | NER loss: 81.393 *
# Epoch 18 | NER loss: 99.750
# Epoch 19 | NER loss: 89.556
# Epoch 20 | NER loss: 63.636 *
# Epoch 21 | NER loss: 72.419
# Epoch 22 | NER loss: 56.912 *
# Epoch 23 | NER loss: 74.976
# Epoch 24 | NER loss: 88.062
# Epoch 25 | NER loss: 79.618
# Epoch 26 | NER loss: 59.909
# Epoch 27 | NER loss: 54.698 *
# Epoch 28 | NER loss: 43.686 *
# Epoch 29 | NER loss: 49.077
# Epoch 30 | NER loss: 49.443
#
# Finished all 30 epochs.
# Best epoch: 28 | Best NER loss: 43.686
# Final-epoch loss: 49.443
# Restored weights from epoch 28.

# %%
plt.figure(figsize=(7,4))
plt.plot(range(1, len(loss_history_m2)+1), loss_history_m2, marker="o")
plt.xlabel("Epoch"); plt.ylabel("NER loss")
plt.title("Custom NER Model 2 — Training Loss (30 epochs, fresh split)")
plt.grid(True, alpha=0.3); plt.tight_layout(); plt.show()

# %%
def doc_to_iob(doc):
    tags = ["O"] * len(doc)
    for ent in doc.ents:
        tags[ent.start] = f"B-{ent.label_}"
        for i in range(ent.start + 1, ent.end):
            tags[i] = f"I-{ent.label_}"
    return tags

def eval_with_seqeval(model, test_docs):
    y_true, y_pred = [], []
    for gold in test_docs:
        pred = model(gold.text)
        y_true.append(doc_to_iob(gold))
        y_pred.append(doc_to_iob(pred))
    return y_true, y_pred

y_true_m2, y_pred_m2 = eval_with_seqeval(nlp2, test_docs_m2)

print("Model 2 — seqeval (entity-level) on fresh test set:")
print(seq_report(y_true_m2, y_pred_m2, digits=4))
print(f"Model 2 overall F1: {seq_f1(y_true_m2, y_pred_m2):.4f}")
# Out:
# Model 2 — seqeval (entity-level) on fresh test set:
#                  precision    recall  f1-score   support
#
#         Amenity     0.5625    0.6207    0.5902        29
#         Cuisine     0.8667    0.7647    0.8125        17
#            Dish     0.3571    0.4167    0.3846        12
#           Hours     0.6667    0.6000    0.6316        10
#        Location     0.5806    0.5455    0.5625        33
#           Price     0.8333    1.0000    0.9091         5
#          Rating     0.6364    0.7778    0.7000         9
# Restaurant_Name     0.4000    0.3333    0.3636        18
#
#       micro avg     0.5865    0.5865    0.5865       133
#       macro avg     0.6129    0.6323    0.6193       133
#    weighted avg     0.5884    0.5865    0.5851       133
#
# Model 2 overall F1: 0.5865

# %%
def score_with_spacy(model, test_docs):
    exs = []
    for gold in test_docs:
        pred = model(gold.text)
        ex = Example(pred, gold)
        exs.append(ex)
    return Scorer().score(exs)

scores_m2 = score_with_spacy(nlp2, test_docs_m2)
print("Model 2 (Scorer) -- P: {:.4f} | R: {:.4f} | F1: {:.4f}".format(
    scores_m2["ents_p"], scores_m2["ents_r"], scores_m2["ents_f"]))

pd.DataFrame([
    {"Entity": lab, "Precision": round(v["p"],4), "Recall": round(v["r"],4), "F1": round(v["f"],4)}
    for lab, v in scores_m2["ents_per_type"].items()
]).sort_values("F1", ascending=False).reset_index(drop=True)
# Out:
# Model 2 (Scorer) -- P: 0.5865 | R: 0.5865 | F1: 0.5865
#             Entity  Precision  Recall      F1
# 0            Price     0.8333  1.0000  0.9091
# 1          Cuisine     0.8667  0.7647  0.8125
# 2           Rating     0.6364  0.7778  0.7000
# 3            Hours     0.6667  0.6000  0.6316
# 4          Amenity     0.5625  0.6207  0.5902
# 5         Location     0.5806  0.5455  0.5625
# 6             Dish     0.3571  0.4167  0.3846
# 7  Restaurant_Name     0.4000  0.3333  0.3636

# %%
def collapse_bio(t): return t[2:] if t.startswith(("B-","I-")) else t

yt = [collapse_bio(t) for s in y_true_m2 for t in s]
yp = [collapse_bio(t) for s in y_pred_m2 for t in s]
labels_cm = sorted(set(yt + yp) - {"O"})

fig, ax = plt.subplots(figsize=(8,6))
cm = confusion_matrix(yt, yp, labels=labels_cm)
ConfusionMatrixDisplay(cm, display_labels=labels_cm).plot(ax=ax, cmap="Blues", values_format="d")
ax.set_title("Custom NER Model 2 — Entity Type Confusion (excl. O)")
plt.xticks(rotation=45, ha="right"); plt.tight_layout(); plt.show()

# %%
def classify_errors(y_true_s, y_pred_s):
    c = Counter()
    for yt, yp in zip(y_true_s, y_pred_s):
        for a, b in zip(yt, yp):
            if a == b: continue
            if a == "O" and b != "O": c["false_positive"] += 1
            elif a != "O" and b == "O": c["false_negative"] += 1
            elif collapse_bio(a) != collapse_bio(b): c["type_mismatch"] += 1
            else: c["boundary_error"] += 1
    return c

err_m2 = classify_errors(y_true_m2, y_pred_m2)
pd.Series(err_m2, name="count").to_frame()
# Out:
#                 count
# false_negative     47
# boundary_error      7
# false_positive     29
# type_mismatch      35

# %% [markdown]
# # Step 9: Inference on Different Domain
# Because our dataset is based on restaurants, a news domain may be a good way to test the application of our NER model.

# %%
import json, random

random.seed(7)

# Same line-by-line JSONL pattern Yarden used for dataset_train.json
conll_tasks = []
with open("../data/raw/conll2003_test.json", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if line:
            conll_tasks.append(json.loads(line))

print(f"Loaded {len(conll_tasks)} CoNLL-2003 sentences")
print("First example keys:", list(conll_tasks[0].keys()))
print("Sample tokens:", conll_tasks[0]["tokens"][:15])
# Out:
# Loaded 3453 CoNLL-2003 sentences
# First example keys: ['tags', 'tokens']
# Sample tokens: ['SOCCER', '-', 'JAPAN', 'GET', 'LUCKY', 'WIN', ',', 'CHINA', 'IN', 'SURPRISE', 'DEFEAT', '.']

# %%
# Reconstruct strings by joining tokens — exactly like Yarden's text_list pattern
all_texts = [" ".join(item["tokens"]) for item in conll_tasks]

# Keep short-to-medium sentences for cleaner inference printouts
candidates = [t for t in all_texts if 6 <= len(t.split()) <= 25]
sample_20 = random.sample(candidates, 20)

print(f"Total sentences: {len(all_texts)} | 6–25 tokens: {len(candidates)} | sampled: 20\n")
for i, s in enumerate(sample_20, 1):
    print(f"{i:02d}. {s}")
# Out:
# Total sentences: 3453 | 6–25 tokens: 1995 | sampled: 20
#
# 01. If it is necessary , I wo n't hesitate to use it , " he said .
# 02. SAN JOSE 10 13 4 69 87 24
# 03. League game on Thursday -LPR- home team in CAPS -RPR- :
# 04. Tropical air carrying sporadic light rains over the coast of Quintana Roo state .
# 05. 22= Anita Wachter -LPR- Austria -RPR- 1:19.21
# 06. SOCCER - BLINKER BAN LIFTED .
# 07. All-rounder Greg Blewett steered his side to a comfortable victory with an unbeaten 57 in 90 balls to the delight of the 42,442 crowd .
# 08. Cowdenbeath 15 7 3 5 22 16 24
# 09. The report , to be debated in parliament in coming weeks , was seen by Reuters on Friday . "
# 10. Pakistan , who arrive next week , are the third team in the triangular World Series tournament .
# 11. Surgeon Renat Akchurin who led the operation , told Itar-Tass news agency Yeltsin was working up to four hours a day at his residence .
# 12. The taxidriver alerted police who arrested a 33-year-old Turkish man when he came to pick up the suitcase at a lost luggage office .
# 13. Ljubljana -LPR- Slovenia -RPR- 9 6 3 15
# 14. Maccabi Petah Tikva 12 6 2 4 14 12 20
# 15. Crude petroleum 2,557 2,832 15,838 17,648
# 16. Zaragoza 15 2 8 5 18 23 14
# 17. Cairns 8-1-35-1 -LPR- w-2 -RPR- , Vaughan 9-1-55-1 , Harris 10-0-42-5 -LPR- w-1 -RPR- ,
# 18. Bowling : Ambrose 10-3-19-0 -LPR- 2nb 1w -RPR- , Walsh 9-0-34-0 -LPR- 4nb -RPR- ,
# 19. Week ago -LPR- est -RPR- 130,000 6,000 346,000
# 20. Indian rubber demand seen outstripping production .

# %%
import re

def looks_like_prose(text):
    toks = text.split()
    if len(toks) < 6 or len(toks) > 25:
        return False
    # Skip lines dominated by numbers / single-letter tokens (box scores, tables)
    alpha_toks = [t for t in toks if re.search(r"[A-Za-z]{3,}", t)]
    if len(alpha_toks) / len(toks) < 0.6:
        return False
    # Must end with sentence-like punctuation
    if text.rstrip()[-1] not in ".!?\"'":
        return False
    return True

candidates = [t for t in all_texts if looks_like_prose(t)]
sample_20 = random.sample(candidates, 20)

print(f"Prose-like candidates: {len(candidates)} | sampled: 20\n")
for i, s in enumerate(sample_20, 1):
    print(f"{i:02d}. {s}")
# Out:
# Prose-like candidates: 799 | sampled: 20
#
# 01. BADMINTON - WORLD GRAND PRIX RESULTS .
# 02. Russ Berrie president to retire in July .
# 03. Last year , Pace became the first sophomore to win the award since its inception in 1970 .
# 04. Delphis Hanover weekly municipal bond yields .
# 05. Holstein - -LPR- weight only -RPR- Select to mostly Choice 2-3 1250-1400 lbs no sales .
# 06. West Indies were all out for 172 off 49.2 overs in the World Series limited overs match against Australia on Friday .
# 07. Supporters of the three pacts say they are only an extension of existing intellectual property rights , covered by the century-old Berne Convention .
# 08. SOCCER - ITALIAN FIRST DIVISION MATCHES THIS WEEKEND .
# 09. The Canadian Wheat Board reported six ships loading , 10 waiting and four due at the Canadian West Coast , as of Friday .
# 10. The newspaper said the girl was rushed to hospital and found to be having extreme difficulty breathing .
# 11. The witnesses could not give exact numbers of those taking part in the march or any other details immediately .
# 12. Italian President urges separatists to turn back .
# 13. CRICKET - LARA SUFFERS MORE AUSTRALIAN TOUR MISERY .
# 14. " There are 500 million messages transmitted through the Internet everyday , " said Tim Casey of the U.S.-based MCI Communications Corporation . "
# 15. Denmark 's Radiometer H1 result seen flat .
# 16. Japan 's authorities seen seeking to rein in dollar .
# 17. Lara looked out of touch during his brief stay at the crease before chipping a simple catch to Shane Warne at mid-wicket .
# 18. Manitoba Pork forward contract PM prices - Dec 6 .
# 19. Lara , disciplined for misconduct on Wednesday , was dismissed for five to extend a disappointing run of form on tour .
# 20. About 350 lots were traded for January and 870 in all months .

# %%
print("="*80)
print("STEP 9 — Inference on out-of-domain data (CoNLL-2003 news, tner/conll2003)")
print("Model: Custom NER Model 2 (trained on MIT Restaurant domain)")
print("="*80 + "\n")

rows = []
for i, text in enumerate(sample_20, 1):
    doc = nlp2(text)
    ents = [(e.text, e.label_) for e in doc.ents]
    print(f"[{i:02d}] {text}")
    if ents:
        for ent_text, ent_lab in ents:
            print(f"       -> {ent_lab:<16} : {ent_text!r}")
    else:
        print(f"       -> (no entities predicted)")
    print()
    rows.append({"idx": i, "text": text,
                 "n_entities": len(ents),
                 "entities": "; ".join(f"{t}/{l}" for t,l in ents)})

df_ood = pd.DataFrame(rows)
print("\nSummary:")
print(f"  Sentences with >=1 prediction : {(df_ood['n_entities']>0).sum()}/20")
print(f"  Total entity predictions       : {df_ood['n_entities'].sum()}")
print(f"  Avg entities per sentence      : {df_ood['n_entities'].mean():.2f}")
df_ood
# Out:
# ================================================================================
# STEP 9 — Inference on out-of-domain data (CoNLL-2003 news, tner/conll2003)
# Model: Custom NER Model 2 (trained on MIT Restaurant domain)
# ================================================================================
#
# [01] BADMINTON - WORLD GRAND PRIX RESULTS .
#        -> Location         : 'PRIX RESULTS .'
#
# [02] Russ Berrie president to retire in July .
#        -> Location         : 'in July .'
#
# [03] Last year , Pace became the first sophomore to win the award since its inception in 1970 .
#        -> Location         : 'year ,'
#        -> Amenity          : 'award since'
#        -> Location         : 'in 1970 .'
#
# [04] Delphis Hanover weekly municipal bond yields .
#        -> Restaurant_Name  : 'municipal bond yields'
#        -> Restaurant_Name  : '.'
#
# [05] Holstein - -LPR- weight only -RPR- Select to mostly Choice 2-3 1250-1400 lbs no sales .
#        -> Dish             : '.'
#
# [06] West Indies were all out for 172 off 49.2 overs in the World Series limited overs match against Australia on Friday .
#        -> Rating           : 'West'
#        -> Amenity          : 'out'
#        -> Hours            : '172 off 49.2'
#        -> Hours            : 'overs in the World'
#        -> Restaurant_Name  : 'limited overs match against'
#        -> Hours            : 'Australia on Friday .'
#
# [07] Supporters of the three pacts say they are only an extension of existing intellectual property rights , covered by the century-old Berne Convention .
#        -> Amenity          : 'they are only'
#        -> Cuisine          : 'property'
#        -> Location         : 'covered by the century-old Berne'
#        -> Restaurant_Name  : '.'
#
# [08] SOCCER - ITALIAN FIRST DIVISION MATCHES THIS WEEKEND .
#        -> Cuisine          : 'ITALIAN'
#        -> Restaurant_Name  : '.'
#
# [09] The Canadian Wheat Board reported six ships loading , 10 waiting and four due at the Canadian West Coast , as of Friday .
#        -> Cuisine          : 'Canadian'
#        -> Dish             : 'reported six ships loading , 10 waiting'
#        -> Rating           : 'four due'
#        -> Cuisine          : 'Canadian'
#        -> Location         : 'West'
#        -> Restaurant_Name  : 'Coast , as'
#        -> Dish             : '.'
#
# [10] The newspaper said the girl was rushed to hospital and found to be having extreme difficulty breathing .
#        -> Dish             : 'found'
#        -> Amenity          : 'difficulty breathing'
#        -> Restaurant_Name  : '.'
#
# [11] The witnesses could not give exact numbers of those taking part in the march or any other details immediately .
#        -> Amenity          : 'witnesses'
#        -> Location         : 'in the march'
#        -> Amenity          : 'other'
#        -> Amenity          : 'details'
#        -> Rating           : 'immediately .'
#
# [12] Italian President urges separatists to turn back .
#        -> Cuisine          : 'Italian'
#        -> Restaurant_Name  : 'urges separatists to'
#        -> Restaurant_Name  : 'back .'
#
# [13] CRICKET - LARA SUFFERS MORE AUSTRALIAN TOUR MISERY .
#        -> Dish             : '.'
#
# [14] " There are 500 million messages transmitted through the Internet everyday , " said Tim Casey of the U.S.-based MCI Communications Corporation . "
#        -> Location         : 'Internet everyday , " said'
#        -> Amenity          : 'Tim'
#        -> Location         : 'U.S.-based MCI'
#        -> Amenity          : 'Communications'
#        -> Cuisine          : '.'
#
# [15] Denmark 's Radiometer H1 result seen flat .
#        -> Hours            : 'Radiometer H1 result'
#        -> Dish             : 'flat .'
#
# [16] Japan 's authorities seen seeking to rein in dollar .
#        -> Restaurant_Name  : 'rein'
#        -> Restaurant_Name  : 'dollar .'
#
# [17] Lara looked out of touch during his brief stay at the crease before chipping a simple catch to Shane Warne at mid-wicket .
#        -> Amenity          : 'looked out of touch during'
#        -> Dish             : 'brief stay'
#        -> Location         : 'crease before chipping'
#        -> Amenity          : 'simple catch to Shane Warne'
#        -> Price            : 'mid-'
#        -> Dish             : '.'
#
# [18] Manitoba Pork forward contract PM prices - Dec 6 .
#        -> Rating           : 'Manitoba Pork forward contract'
#        -> Price            : 'PM prices'
#        -> Hours            : '6 .'
#
# [19] Lara , disciplined for misconduct on Wednesday , was dismissed for five to extend a disappointing run of form on tour .
#        -> Amenity          : 'disciplined'
#        -> Hours            : 'misconduct on Wednesday ,'
#        -> Amenity          : 'dismissed'
#        -> Amenity          : 'disappointing'
#        -> Location         : 'on tour .'
#
# [20] About 350 lots were traded for January and 870 in all months .
#        -> Hours            : '870 in all'
#        -> Rating           : 'months'
#        -> Dish             : '.'
#
#
# Summary:
#   Sentences with >=1 prediction : 20/20
#   Total entity predictions       : 65
#   Avg entities per sentence      : 3.25
#     idx                                               text  n_entities  \
# 0     1             BADMINTON - WORLD GRAND PRIX RESULTS .           1
# 1     2          Russ Berrie president to retire in July .           1
# 2     3  Last year , Pace became the first sophomore to...           3
# 3     4     Delphis Hanover weekly municipal bond yields .           2
# 4     5  Holstein - -LPR- weight only -RPR- Select to m...           1
# 5     6  West Indies were all out for 172 off 49.2 over...           6
# 6     7  Supporters of the three pacts say they are onl...           4
# 7     8  SOCCER - ITALIAN FIRST DIVISION MATCHES THIS W...           2
# 8     9  The Canadian Wheat Board reported six ships lo...           7
# 9    10  The newspaper said the girl was rushed to hosp...           3
# 10   11  The witnesses could not give exact numbers of ...           5
# 11   12  Italian President urges separatists to turn ba...           3
# 12   13  CRICKET - LARA SUFFERS MORE AUSTRALIAN TOUR MI...           1
# 13   14  " There are 500 million messages transmitted t...           5
# 14   15        Denmark 's Radiometer H1 result seen flat .           2
# 15   16  Japan 's authorities seen seeking to rein in d...           2
# 16   17  Lara looked out of touch during his brief stay...           6
# 17   18  Manitoba Pork forward contract PM prices - Dec...           3
# 18   19  Lara , disciplined for misconduct on Wednesday...           5
# 19   20  About 350 lots were traded for January and 870...           3
#
#                                              entities
# 0                             PRIX RESULTS ./Location
# 1                                  in July ./Location
# 2   year ,/Location; award since/Amenity; in 1970 ...
# 3   municipal bond yields/Restaurant_Name; ./Resta...
# 4                                              ./Dish
# 5   West/Rating; out/Amenity; 172 off 49.2/Hours; ...
# 6   they are only/Amenity; property/Cuisine; cover...
# 7                  ITALIAN/Cuisine; ./Restaurant_Name
# 8   Canadian/Cuisine; reported six ships loading ,...
# 9   found/Dish; difficulty breathing/Amenity; ./Re...
# 10  witnesses/Amenity; in the march/Location; othe...
# 11  Italian/Cuisine; urges separatists to/Restaura...
# 12                                             ./Dish
# 13  Internet everyday , " said/Location; Tim/Ameni...
# 14            Radiometer H1 result/Hours; flat ./Dish
# 15     rein/Restaurant_Name; dollar ./Restaurant_Name
# 16  looked out of touch during/Amenity; brief stay...
# 17  Manitoba Pork forward contract/Rating; PM pric...
# 18  disciplined/Amenity; misconduct on Wednesday ,...
# 19            870 in all/Hours; months/Rating; ./Dish

# %%
from collections import Counter
label_counter = Counter()
for text in sample_20:
    for e in nlp2(text).ents:
        label_counter[e.label_] += 1

print("Predicted-label distribution on out-of-domain news sample:")
for lab, n in label_counter.most_common():
    print(f"  {lab:<18} {n}")
# Out:
# Predicted-label distribution on out-of-domain news sample:
#   Amenity            14
#   Location           11
#   Restaurant_Name    11
#   Dish               9
#   Hours              7
#   Cuisine            6
#   Rating             5
#   Price              2

# %% [markdown]
# # Step 9 Summary
# We applied the Custom NER Model 2 (our best model) onto 20 sentences from the CoNLL-2003 news dataset to evaluate whether or not the model performs well in another domain and if it can generalize entities. Overall, the performance on news text was poor due to the following:
#
# - Interpretation of any numbers as Hours, since the model has learned to associate numbers in the original dataset with restaurant hours
# - Capitalization of certain words (names, countries, etc) have been interpreted mostly as locations or restaurant names.
# - Words like "Indian" or "Crude" were interpreted as a cuisine, even though their meaning in the news is entirely different.
#
# Overall, the ability for our model to generalize in a different domain is poor, given that it has been specifically trained to interpret words solely in the context of restaurants or foods.
