# %%
# ============================================================
# SETUP: Install and import spaCy
# ============================================================
# spaCy is pre-installed in Colab. If running locally:
# !pip install spacy
# !python -m spacy download en_core_web_sm

import spacy
from spacy import displacy

# Load the small English model
# This model was trained on web text (blogs, news, comments)
# It recognizes entities like PERSON, ORG, GPE, DATE, MONEY, etc.
nlp = spacy.load("en_core_web_sm")

print(f"Model loaded: {nlp.meta['name']}")
print(f"Pipeline components: {nlp.pipe_names}")
# Out:
# Model loaded: core_web_sm
# Pipeline components: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
# ============================================================
# BASIC NER: Process a single sentence
# ============================================================
# nlp() processes text and returns a Doc object with all annotations

text = "Thomas Jefferson writes the Declaration of Independence"
doc = nlp(text)

# Loop through detected entities
# Each entity has:
#   .text       → the actual text span (e.g., "Thomas Jefferson")
#   .start_char → character position where entity starts
#   .end_char   → character position where entity ends
#   .label_     → entity type label (e.g., "PERSON")

print(f"Text: {text}")
print(f"{'Entity':<30} {'Start':>5} {'End':>5}  {'Label'}")
print("-" * 60)
for ent in doc.ents:
    print(f"{ent.text:<30} {ent.start_char:>5} {ent.end_char:>5}  {ent.label_}")
# Out:
# Text: Thomas Jefferson writes the Declaration of Independence
# Entity                         Start   End  Label
# ------------------------------------------------------------
# Thomas Jefferson                   0    16  PERSON
# the Declaration of Independence    24    55  WORK_OF_ART

# %%
# ============================================================
# VISUALIZATION: Use displaCy to render entities inline
# ============================================================
# displaCy highlights entities directly in the text
# style="ent" → entity visualization (vs "dep" for dependency parsing)
# jupyter=True → render inline in notebook

displacy.render(doc, style="ent", jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thomas Jefferson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Declaration of Independence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# </div></span>

# %%
# ============================================================
# BATCH PROCESSING: Run NER on multiple sentences
# ============================================================
# Let's test with various sentences to see what spaCy catches
# and what it misses — this builds intuition for NER limitations

texts = [
    "Thomas Jefferson writes the Declaration of Independence",
    "My friend Tom spends his time google at work",        # lowercase 'google' = verb
    "My friend Tom works at Google",                        # capitalized 'Google' = ORG
    "Lin Manuel-Miranda writes Hamilton the musical",
    "Washington is a rainy state.",                          # GPE or PERSON?
    "Apple announced record revenue of $81.8 billion in Q3 2024",
    "Dr. Sarah Chen published a paper on deep learning at MIT",
]

for text in texts:
    doc = nlp(text)
    print(f"\nText: {text}")

    # Render the entity visualization
    displacy.render(doc, style="ent", jupyter=True, options={'distance': 120})

    # Also print entities in structured format
    for ent in doc.ents:
        print(f"  → {ent.text:<25} {ent.label_:<10} ({ent.start_char}-{ent.end_char})")

    if not doc.ents:
        print("  → No entities detected!")
# Out:
# Text: Thomas Jefferson writes the Declaration of Independence
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thomas Jefferson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Declaration of Independence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# </div></span>
#   → Thomas Jefferson          PERSON     (0-16)
#   → the Declaration of Independence WORK_OF_ART (24-55)
#
# Text: My friend Tom spends his time google at work
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">My friend
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  spends his time google at work</div></span>
#   → Tom                       PERSON     (10-13)
#
# Text: My friend Tom works at Google
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">My friend
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  works at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>
#   → Tom                       PERSON     (10-13)
#   → Google                    ORG        (23-29)
#
# Text: Lin Manuel-Miranda writes Hamilton the musical
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lin Manuel-Miranda
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hamilton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  the musical</div></span>
#   → Lin Manuel-Miranda        PERSON     (0-18)
#   → Hamilton                  PERSON     (26-34)
#
# Text: Washington is a rainy state.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is a rainy state.</div></span>
#   → Washington                GPE        (0-10)
#
# Text: Apple announced record revenue of $81.8 billion in Q3 2024
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  announced record revenue of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $81.8 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Q3 2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div></span>
#   → Apple                     ORG        (0-5)
#   → $81.8 billion             MONEY      (34-47)
#   → Q3 2024                   DATE       (51-58)
#
# Text: Dr. Sarah Chen published a paper on deep learning at MIT
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sarah Chen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  published a paper on deep learning at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MIT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>
#   → Sarah Chen                PERSON     (4-14)
#   → MIT                       ORG        (53-56)

# %%
import json
import re

with open('batch1_20docs_export.json', "r", encoding="utf-8") as f:
    tasks = json.load(f)

def get_tokens(text):
    return list(re.finditer(r"\S+", text))

def make_binary_labels(text, results):
    tokens = get_tokens(text)
    labels = [0] * len(tokens)

    for item in results:
        if item["type"] == "labels":
            start = item["value"]["start"]
            end = item["value"]["end"]

            for i, tok in enumerate(tokens):
                if tok.start() < end and tok.end() > start:
                    labels[i] = 1

    return labels

# %%
tasks
# Out:
# [{'id': 260729187,
#   'annotations': [{'id': 93272034,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'JkkKkt37Z2',
#       'type': 'labels',
#       'value': {'end': 38,
#        'text': 'burger king',
#        'start': 27,
#        'labels': ['Restaurant_Name']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': '309AWIYJMU',
#       'type': 'labels',
#       'value': {'end': 26, 'text': 'closed', 'start': 20, 'labels': ['Hours']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-11T21:21:57.428637Z',
#     'updated_at': '2026-04-11T21:21:57.428648Z',
#     'draft_created_at': '2026-04-11T21:21:43.493670Z',
#     'lead_time': 29.322,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '9383dbde-081d-461f-9ea0-5dc5cf08320c',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729187,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93274682,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'M0ZAkWlANQ',
#       'type': 'labels',
#       'value': {'end': 26, 'text': 'closed', 'start': 20, 'labels': ['Hours']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'K6qV-vwBYU',
#       'type': 'labels',
#       'value': {'end': 38,
#        'text': 'burger king',
#        'start': 27,
#        'labels': ['Restaurant_Name']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'ACCEPTED',
#     'reviews': [{'id': 9296892,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:45:30.745522Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274682,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101100,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': 'M0ZAkWlANQ',
#         'type': 'labels',
#         'value': {'end': 26,
#          'text': 'closed',
#          'start': 20,
#          'labels': ['Hours']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': 'K6qV-vwBYU',
#         'type': 'labels',
#         'value': {'end': 38,
#          'text': 'burger king',
#          'start': 27,
#          'labels': ['Restaurant_Name']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]},
#      {'id': 9296893,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:45:38.445105Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274682,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101269,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': 'M0ZAkWlANQ',
#         'type': 'labels',
#         'value': {'end': 26,
#          'text': 'closed',
#          'start': 20,
#          'labels': ['Hours']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': 'K6qV-vwBYU',
#         'type': 'labels',
#         'value': {'end': 38,
#          'text': 'burger king',
#          'start': 27,
#          'labels': ['Restaurant_Name']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]},
#      {'id': 9296894,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:45:43.496603Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274682,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101273,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': 'M0ZAkWlANQ',
#         'type': 'labels',
#         'value': {'end': 26,
#          'text': 'closed',
#          'start': 20,
#          'labels': ['Hours']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': 'K6qV-vwBYU',
#         'type': 'labels',
#         'value': {'end': 38,
#          'text': 'burger king',
#          'start': 27,
#          'labels': ['Restaurant_Name']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T02:38:42.893365Z',
#     'updated_at': '2026-04-12T02:38:42.893376Z',
#     'draft_created_at': '2026-04-12T02:30:10.749808Z',
#     'lead_time': 465.277,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': 'be6e5df0-47c6-4346-9b85-846e86defb9a',
#     'import_id': None,
#     'last_action': 'accepted',
#     'bulk_created': False,
#     'task': 260729187,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 100.0,
#   'data': {'text': 'can you find me the closed burger king'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.065070Z',
#   'updated_at': '2026-04-12T02:45:43.672819Z',
#   'allow_skip': True,
#   'inner_id': 2,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': []},
#  {'id': 260729188,
#   'annotations': [{'id': 93272060,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'uDcOoebGdO',
#       'type': 'labels',
#       'value': {'end': 46,
#        'text': 'cheesecake factory',
#        'start': 28,
#        'labels': ['Restaurant_Name']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'WNxENsp1nW',
#       'type': 'labels',
#       'value': {'end': 27,
#        'text': 'closest',
#        'start': 20,
#        'labels': ['Location']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-11T21:24:58.720639Z',
#     'updated_at': '2026-04-11T21:24:58.720650Z',
#     'draft_created_at': '2026-04-11T21:24:51.848307Z',
#     'lead_time': 19.04,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': 'd4794339-c86b-40d2-a69f-6641ac460bf9',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729188,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93274680,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': '4QXCM9yqGs',
#       'type': 'labels',
#       'value': {'end': 27,
#        'text': 'closest',
#        'start': 20,
#        'labels': ['Location']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'wqfnNvEJH9',
#       'type': 'labels',
#       'value': {'end': 46,
#        'text': 'cheesecake factory',
#        'start': 28,
#        'labels': ['Restaurant_Name']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'ACCEPTED',
#     'reviews': [{'id': 9296895,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:45:49.600070Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274680,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101098,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': '4QXCM9yqGs',
#         'type': 'labels',
#         'value': {'end': 27,
#          'text': 'closest',
#          'start': 20,
#          'labels': ['Location']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': 'wqfnNvEJH9',
#         'type': 'labels',
#         'value': {'end': 46,
#          'text': 'cheesecake factory',
#          'start': 28,
#          'labels': ['Restaurant_Name']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T02:38:24.285514Z',
#     'updated_at': '2026-04-12T02:38:24.285526Z',
#     'draft_created_at': '2026-04-12T02:38:12.732772Z',
#     'lead_time': 13.434999999999999,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': 'c839a642-0014-4c18-834a-49ddaeb60653',
#     'import_id': None,
#     'last_action': 'accepted',
#     'bulk_created': False,
#     'task': 260729188,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 100.0,
#   'data': {'text': 'can you find me the closest cheesecake factory'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.065114Z',
#   'updated_at': '2026-04-12T02:45:49.840241Z',
#   'allow_skip': True,
#   'inner_id': 3,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': []},
#  {'id': 260729189,
#   'annotations': [{'id': 93272076,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'xcf9_05lW0',
#       'type': 'labels',
#       'value': {'end': 37,
#        'text': 'mc donalds',
#        'start': 27,
#        'labels': ['Restaurant_Name']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'AcdN10xoYD',
#       'type': 'labels',
#       'value': {'end': 26,
#        'text': 'closet',
#        'start': 20,
#        'labels': ['Location']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-11T21:26:45.907279Z',
#     'updated_at': '2026-04-11T21:26:45.907296Z',
#     'draft_created_at': '2026-04-11T21:22:27.545248Z',
#     'lead_time': 40.176,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '027e321a-e3dd-4726-b09b-62e54686b71a',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729189,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93274688,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'DxK7Z1KLBv',
#       'type': 'labels',
#       'value': {'end': 26,
#        'text': 'closet',
#        'start': 20,
#        'labels': ['Location']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'rGOuFAoXCn',
#       'type': 'labels',
#       'value': {'end': 37,
#        'text': 'mc donalds',
#        'start': 27,
#        'labels': ['Restaurant_Name']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'ACCEPTED',
#     'reviews': [{'id': 9296896,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:45:58.682853Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274688,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101106,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': 'DxK7Z1KLBv',
#         'type': 'labels',
#         'value': {'end': 26,
#          'text': 'closet',
#          'start': 20,
#          'labels': ['Location']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': 'rGOuFAoXCn',
#         'type': 'labels',
#         'value': {'end': 37,
#          'text': 'mc donalds',
#          'start': 27,
#          'labels': ['Restaurant_Name']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T02:39:06.364104Z',
#     'updated_at': '2026-04-12T02:39:06.364114Z',
#     'draft_created_at': None,
#     'lead_time': 6.857,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '582a2e3a-a1a9-473e-8dd4-a69d3acf2999',
#     'import_id': None,
#     'last_action': 'accepted',
#     'bulk_created': False,
#     'task': 260729189,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 100.0,
#   'data': {'text': 'can you find me the closet mc donalds'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.065149Z',
#   'updated_at': '2026-04-12T02:45:58.881166Z',
#   'allow_skip': True,
#   'inner_id': 4,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 1,
#   'unresolved_comment_count': 1,
#   'last_comment_updated_at': '2026-04-11T21:22:46.688336Z',
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': [149661]},
#  {'id': 260729190,
#   'annotations': [{'id': 93272073,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'L95mRoMhQV',
#       'type': 'labels',
#       'value': {'end': 36,
#        'text': 'coast line grill',
#        'start': 20,
#        'labels': ['Restaurant_Name']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'JbZmaQ9S0B',
#       'type': 'labels',
#       'value': {'end': 43,
#        'text': 'nearby',
#        'start': 37,
#        'labels': ['Location']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'CHiqgvJ3KL',
#       'type': 'labels',
#       'value': {'end': 67,
#        'text': 'seating at the bar',
#        'start': 49,
#        'labels': ['Amenity']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-11T21:26:29.277484Z',
#     'updated_at': '2026-04-11T21:26:29.277501Z',
#     'draft_created_at': '2026-04-11T21:26:15.236667Z',
#     'lead_time': 28.78,
#     'prediction': {},
#     'result_count': 3,
#     'unique_id': '542a5904-a79d-46b3-adca-df547adfc535',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729190,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93274701,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': '1sy76Neca8',
#       'type': 'labels',
#       'value': {'end': 36,
#        'text': 'coast line grill',
#        'start': 20,
#        'labels': ['Restaurant_Name']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'TFJW038oMC',
#       'type': 'labels',
#       'value': {'end': 43,
#        'text': 'nearby',
#        'start': 37,
#        'labels': ['Location']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': '-BxhvxPPvR',
#       'type': 'labels',
#       'value': {'end': 67,
#        'text': 'seating at the bar',
#        'start': 49,
#        'labels': ['Amenity']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'ACCEPTED',
#     'reviews': [{'id': 9296897,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:46:05.153591Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274701,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101120,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': '1sy76Neca8',
#         'type': 'labels',
#         'value': {'end': 36,
#          'text': 'coast line grill',
#          'start': 20,
#          'labels': ['Restaurant_Name']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': 'TFJW038oMC',
#         'type': 'labels',
#         'value': {'end': 43,
#          'text': 'nearby',
#          'start': 37,
#          'labels': ['Location']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': '-BxhvxPPvR',
#         'type': 'labels',
#         'value': {'end': 67,
#          'text': 'seating at the bar',
#          'start': 49,
#          'labels': ['Amenity']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T02:39:46.255426Z',
#     'updated_at': '2026-04-12T02:39:46.255437Z',
#     'draft_created_at': '2026-04-12T02:39:19.759000Z',
#     'lead_time': 33.82,
#     'prediction': {},
#     'result_count': 3,
#     'unique_id': 'bdedf250-909c-46fc-8b76-00acda77cc49',
#     'import_id': None,
#     'last_action': 'accepted',
#     'bulk_created': False,
#     'task': 260729190,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 100.0,
#   'data': {'text': 'can you find me the coast line grill nearby with seating at the bar'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.065185Z',
#   'updated_at': '2026-04-12T02:46:05.351111Z',
#   'allow_skip': True,
#   'inner_id': 5,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': []},
#  {'id': 260729191,
#   'annotations': [{'id': 93272084,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'mxddmfDAZM',
#       'type': 'labels',
#       'value': {'end': 40,
#        'text': 'daisy gs',
#        'start': 32,
#        'labels': ['Restaurant_Name']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': '0cdPXeWk5P',
#       'type': 'labels',
#       'value': {'end': 60,
#        'text': 'hotel dining',
#        'start': 48,
#        'labels': ['Amenity']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-11T21:27:26.175373Z',
#     'updated_at': '2026-04-11T21:27:26.175387Z',
#     'draft_created_at': '2026-04-11T21:27:22.400954Z',
#     'lead_time': 30.886,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '6f7c4aba-1d1f-46e4-bb62-0ebdf3f20ad3',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729191,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93274708,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'fMtaAIobNV',
#       'type': 'labels',
#       'value': {'end': 40,
#        'text': 'daisy gs',
#        'start': 32,
#        'labels': ['Restaurant_Name']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'nYbHzCd5Di',
#       'type': 'labels',
#       'value': {'end': 60,
#        'text': 'hotel dining',
#        'start': 48,
#        'labels': ['Amenity']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'ACCEPTED',
#     'reviews': [{'id': 9296899,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:46:35.782594Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274708,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101301,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': 'fMtaAIobNV',
#         'type': 'labels',
#         'value': {'end': 40,
#          'text': 'daisy gs',
#          'start': 32,
#          'labels': ['Restaurant_Name']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': 'nYbHzCd5Di',
#         'type': 'labels',
#         'value': {'end': 60,
#          'text': 'hotel dining',
#          'start': 48,
#          'labels': ['Amenity']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]},
#      {'id': 9296902,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:51:49.708175Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274708,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101302,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': 'fMtaAIobNV',
#         'type': 'labels',
#         'value': {'end': 40,
#          'text': 'daisy gs',
#          'start': 32,
#          'labels': ['Restaurant_Name']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': 'nYbHzCd5Di',
#         'type': 'labels',
#         'value': {'end': 60,
#          'text': 'hotel dining',
#          'start': 48,
#          'labels': ['Amenity']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]},
#      {'id': 9296898,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:46:35.275217Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274708,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101127,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': 'fMtaAIobNV',
#         'type': 'labels',
#         'value': {'end': 40,
#          'text': 'daisy gs',
#          'start': 32,
#          'labels': ['Restaurant_Name']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': 'nYbHzCd5Di',
#         'type': 'labels',
#         'value': {'end': 60,
#          'text': 'hotel dining',
#          'start': 48,
#          'labels': ['Amenity']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T02:40:08.063589Z',
#     'updated_at': '2026-04-12T02:40:08.063601Z',
#     'draft_created_at': '2026-04-12T02:40:01.671485Z',
#     'lead_time': 16.44,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '58399560-ab4d-47b8-8346-64a96a95fd1f',
#     'import_id': None,
#     'last_action': 'accepted',
#     'bulk_created': False,
#     'task': 260729191,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 100.0,
#   'data': {'text': 'can you find me the location of daisy gs it has hotel dining'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.065219Z',
#   'updated_at': '2026-04-12T02:51:49.919198Z',
#   'allow_skip': True,
#   'inner_id': 6,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': []},
#  {'id': 260729192,
#   'annotations': [{'id': 93272090,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': '91SN0p2-4X',
#       'type': 'labels',
#       'value': {'end': 27,
#        'text': 'nearest',
#        'start': 20,
#        'labels': ['Location']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': '2FjVwnUYNJ',
#       'type': 'labels',
#       'value': {'end': 37,
#        'text': 'mcdonalds',
#        'start': 28,
#        'labels': ['Restaurant_Name']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-11T21:28:51.873008Z',
#     'updated_at': '2026-04-11T21:28:51.873020Z',
#     'draft_created_at': '2026-04-11T21:28:49.991905Z',
#     'lead_time': 13.675,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '5562e13c-db1f-4fde-be72-70239264e1e8',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729192,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93274712,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': '-4prp-0CZA',
#       'type': 'labels',
#       'value': {'end': 27,
#        'text': 'nearest',
#        'start': 20,
#        'labels': ['Location']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'OyMVw_5lVV',
#       'type': 'labels',
#       'value': {'end': 37,
#        'text': 'mcdonalds',
#        'start': 28,
#        'labels': ['Restaurant_Name']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'ACCEPTED',
#     'reviews': [{'id': 9296909,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:54:58.770772Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274712,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101131,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': '-4prp-0CZA',
#         'type': 'labels',
#         'value': {'end': 27,
#          'text': 'nearest',
#          'start': 20,
#          'labels': ['Location']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': 'OyMVw_5lVV',
#         'type': 'labels',
#         'value': {'end': 37,
#          'text': 'mcdonalds',
#          'start': 28,
#          'labels': ['Restaurant_Name']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T02:40:19.483011Z',
#     'updated_at': '2026-04-12T02:40:19.483022Z',
#     'draft_created_at': None,
#     'lead_time': 5.265,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': 'c3857909-57bc-4224-8413-4e727caa95cb',
#     'import_id': None,
#     'last_action': 'accepted',
#     'bulk_created': False,
#     'task': 260729192,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 100.0,
#   'data': {'text': 'can you find me the nearest mcdonalds'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.065253Z',
#   'updated_at': '2026-04-12T02:54:58.967147Z',
#   'allow_skip': True,
#   'inner_id': 7,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': []},
#  {'id': 260729193,
#   'annotations': [{'id': 93274391,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'Vj7GlzAdir',
#       'type': 'labels',
#       'value': {'end': 36,
#        'text': 'pizzeria',
#        'start': 28,
#        'labels': ['Dish']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'jhfDceSvmL',
#       'type': 'labels',
#       'value': {'end': 27,
#        'text': 'nearest',
#        'start': 20,
#        'labels': ['Location']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T01:54:33.903287Z',
#     'updated_at': '2026-04-12T01:54:33.903300Z',
#     'draft_created_at': '2026-04-12T01:54:27.381819Z',
#     'lead_time': 15690.798,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '9ca45fe8-2fc1-4dc5-b4c2-7a8d421312ed',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729193,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93274718,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': '9-k1NYkpPY',
#       'type': 'labels',
#       'value': {'end': 27,
#        'text': 'nearest',
#        'start': 20,
#        'labels': ['Location']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'Tg9myUpoa0',
#       'type': 'labels',
#       'value': {'end': 36,
#        'text': 'pizzeria',
#        'start': 28,
#        'labels': ['Cuisine']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'ACCEPTED',
#     'reviews': [{'id': 9296904,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:52:13.007437Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274718,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101137,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': '9-k1NYkpPY',
#         'type': 'labels',
#         'value': {'end': 27,
#          'text': 'nearest',
#          'start': 20,
#          'labels': ['Location']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': 'Tg9myUpoa0',
#         'type': 'labels',
#         'value': {'end': 36,
#          'text': 'pizzeria',
#          'start': 28,
#          'labels': ['Cuisine']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T02:40:39.144916Z',
#     'updated_at': '2026-04-12T02:40:39.144927Z',
#     'draft_created_at': '2026-04-12T02:40:33.730693Z',
#     'lead_time': 13.443,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '95ff3da7-b322-4e5f-98f3-64fe38818c46',
#     'import_id': None,
#     'last_action': 'accepted',
#     'bulk_created': False,
#     'task': 260729193,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 50.0,
#   'data': {'text': 'can you find me the nearest pizzeria'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.065286Z',
#   'updated_at': '2026-04-12T02:52:13.213523Z',
#   'allow_skip': True,
#   'inner_id': 8,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': []},
#  {'id': 260729194,
#   'annotations': [{'id': 93272107,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': '77C11yKcz6',
#       'type': 'labels',
#       'value': {'end': 26,
#        'text': 'nicest',
#        'start': 20,
#        'labels': ['Rating']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'hTXR0QhRXQ',
#       'type': 'labels',
#       'value': {'end': 54,
#        'text': 'italian food',
#        'start': 42,
#        'labels': ['Cuisine']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-11T21:30:43.080704Z',
#     'updated_at': '2026-04-11T21:30:43.080716Z',
#     'draft_created_at': '2026-04-11T21:29:47.877390Z',
#     'lead_time': 73.654,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '9aea8228-9ca9-49f7-9f85-4723903683d2',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729194,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93274732,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'zIqI_AbjOt',
#       'type': 'labels',
#       'value': {'end': 26,
#        'text': 'nicest',
#        'start': 20,
#        'labels': ['Rating']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'vkJ7Mj-2e6',
#       'type': 'labels',
#       'value': {'end': 54,
#        'text': 'italian food',
#        'start': 42,
#        'labels': ['Cuisine']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'ACCEPTED',
#     'reviews': [{'id': 9296905,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:52:29.178404Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274732,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101151,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': 'zIqI_AbjOt',
#         'type': 'labels',
#         'value': {'end': 26,
#          'text': 'nicest',
#          'start': 20,
#          'labels': ['Rating']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': 'vkJ7Mj-2e6',
#         'type': 'labels',
#         'value': {'end': 54,
#          'text': 'italian food',
#          'start': 42,
#          'labels': ['Cuisine']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T02:41:07.595380Z',
#     'updated_at': '2026-04-12T02:41:07.595392Z',
#     'draft_created_at': None,
#     'lead_time': 11.322,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '59a5d636-afe8-4ce5-9449-5e6705e54afb',
#     'import_id': None,
#     'last_action': 'accepted',
#     'bulk_created': False,
#     'task': 260729194,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 100.0,
#   'data': {'text': 'can you find me the nicest restaurant for italian food'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.065318Z',
#   'updated_at': '2026-04-12T02:52:29.387349Z',
#   'allow_skip': True,
#   'inner_id': 9,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': []},
#  {'id': 260729195,
#   'annotations': [{'id': 93272111,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'G7V0KZHib8',
#       'type': 'labels',
#       'value': {'end': 41,
#        'text': 'ihop',
#        'start': 37,
#        'labels': ['Restaurant_Name']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'EdgulmVlXb',
#       'type': 'labels',
#       'value': {'end': 59,
#        'text': 'tilburg street',
#        'start': 45,
#        'labels': ['Location']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-11T21:31:24.168856Z',
#     'updated_at': '2026-04-11T21:31:24.168868Z',
#     'draft_created_at': '2026-04-11T21:31:16.406813Z',
#     'lead_time': 21.834,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '9424c5bc-5a43-4aae-9fe4-b44000865957',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729195,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93274741,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'AuwYkCh2Q5',
#       'type': 'labels',
#       'value': {'end': 41,
#        'text': 'ihop',
#        'start': 37,
#        'labels': ['Restaurant_Name']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'q85cVKB3jZ',
#       'type': 'labels',
#       'value': {'end': 59,
#        'text': 'tilburg street',
#        'start': 45,
#        'labels': ['Location']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'ACCEPTED',
#     'reviews': [{'id': 9296906,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:52:56.842885Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274741,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101160,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': 'AuwYkCh2Q5',
#         'type': 'labels',
#         'value': {'end': 41,
#          'text': 'ihop',
#          'start': 37,
#          'labels': ['Restaurant_Name']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': 'q85cVKB3jZ',
#         'type': 'labels',
#         'value': {'end': 59,
#          'text': 'tilburg street',
#          'start': 45,
#          'labels': ['Location']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T02:41:26.183741Z',
#     'updated_at': '2026-04-12T02:41:26.183752Z',
#     'draft_created_at': None,
#     'lead_time': 10.597,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': 'd1caab54-dfcb-4814-a243-b57cc91ea112',
#     'import_id': None,
#     'last_action': 'accepted',
#     'bulk_created': False,
#     'task': 260729195,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 100.0,
#   'data': {'text': 'can you find me the phone number for ihop on tilburg street'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.065350Z',
#   'updated_at': '2026-04-12T02:52:57.055935Z',
#   'allow_skip': True,
#   'inner_id': 10,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': []},
#  {'id': 260729196,
#   'annotations': [{'id': 93272118,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'yocm7XNXR_',
#       'type': 'labels',
#       'value': {'end': 52,
#        'text': 'best reviews',
#        'start': 40,
#        'labels': ['Rating']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-11T21:32:25.587472Z',
#     'updated_at': '2026-04-11T21:32:25.587487Z',
#     'draft_created_at': '2026-04-11T21:32:15.757825Z',
#     'lead_time': 49.496,
#     'prediction': {},
#     'result_count': 1,
#     'unique_id': 'b16aa328-8b89-47c5-b2b5-5424779657a1',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729196,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93274746,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'NSfZkOe73G',
#       'type': 'labels',
#       'value': {'end': 52,
#        'text': 'best reviews',
#        'start': 40,
#        'labels': ['Rating']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'ACCEPTED',
#     'reviews': [{'id': 9296908,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:53:16.097886Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274746,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101405,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': 'NSfZkOe73G',
#         'type': 'labels',
#         'value': {'end': 52,
#          'text': 'best reviews',
#          'start': 40,
#          'labels': ['Rating']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]},
#      {'id': 9296907,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-12T02:53:09.485903Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93274746,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102101165,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': 'NSfZkOe73G',
#         'type': 'labels',
#         'value': {'end': 52,
#          'text': 'best reviews',
#          'start': 40,
#          'labels': ['Rating']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T02:41:36.198516Z',
#     'updated_at': '2026-04-12T02:41:36.198527Z',
#     'draft_created_at': None,
#     'lead_time': 3.827,
#     'prediction': {},
#     'result_count': 1,
#     'unique_id': '35316fa7-71f1-4d62-9fd1-1db7bf37b240',
#     'import_id': None,
#     'last_action': 'accepted',
#     'bulk_created': False,
#     'task': 260729196,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 100.0,
#   'data': {'text': 'can you find me the restaurant with the best reviews'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.065381Z',
#   'updated_at': '2026-04-12T02:53:16.312132Z',
#   'allow_skip': True,
#   'inner_id': 11,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': []},
#  {'id': 260729402,
#   'annotations': [{'id': 93303536,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'YZqFMML5pB',
#       'type': 'labels',
#       'value': {'end': 15, 'text': 'cheap', 'start': 10, 'labels': ['Price']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'pa4COFfOxL',
#       'type': 'labels',
#       'value': {'end': 22,
#        'text': 'vegan ',
#        'start': 16,
#        'labels': ['Cuisine']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'ZQ6sgb40HE',
#       'type': 'labels',
#       'value': {'end': 52,
#        'text': 'in the theater district',
#        'start': 29,
#        'labels': ['Location']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-13T02:33:33.182527Z',
#     'updated_at': '2026-04-13T02:33:33.182538Z',
#     'draft_created_at': '2026-04-13T02:33:23.459815Z',
#     'lead_time': 25.494,
#     'prediction': {},
#     'result_count': 3,
#     'unique_id': '845e4812-0206-41d3-88e3-31cfd0960618',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729402,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93304118,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'AbMycLUXKv',
#       'type': 'labels',
#       'value': {'end': 15, 'text': 'cheap', 'start': 10, 'labels': ['Price']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'uQkrsgssmd',
# ...
#       'type': 'labels',
#       'value': {'end': 22,
#        'text': 'reviews',
#        'start': 15,
#        'labels': ['Rating']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-13T02:37:29.455596Z',
#     'updated_at': '2026-04-13T02:37:29.455609Z',
#     'draft_created_at': '2026-04-13T02:37:21.230790Z',
#     'lead_time': 23.249,
#     'prediction': {},
#     'result_count': 3,
#     'unique_id': '02ad87fb-a04b-4d97-a716-5d779a8605a2',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729407,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 100.0,
#   'data': {'text': 'chinese buffet reviews'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.072392Z',
#   'updated_at': '2026-04-13T02:45:00.915721Z',
#   'allow_skip': True,
#   'inner_id': 222,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': []},
#  {'id': 260729408,
#   'annotations': [{'id': 93301204,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'upotJFL3FV',
#       'type': 'labels',
#       'value': {'end': 14,
#        'text': 'buffet',
#        'start': 8,
#        'labels': ['Amenity']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': '_VGrUcOwCB',
#       'type': 'labels',
#       'value': {'end': 7,
#        'text': 'chinese',
#        'start': 0,
#        'labels': ['Cuisine']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'ACCEPTED',
#     'reviews': [{'id': 9299237,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-13T02:45:09.051353Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93301204,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102130053,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': 'upotJFL3FV',
#         'type': 'labels',
#         'value': {'end': 14,
#          'text': 'buffet',
#          'start': 8,
#          'labels': ['Amenity']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': '_VGrUcOwCB',
#         'type': 'labels',
#         'value': {'end': 7,
#          'text': 'chinese',
#          'start': 0,
#          'labels': ['Cuisine']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T23:39:09.489428Z',
#     'updated_at': '2026-04-12T23:39:09.489439Z',
#     'draft_created_at': None,
#     'lead_time': 9.58,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '86037557-ac6a-4fef-aca8-430ae193ec1a',
#     'import_id': None,
#     'last_action': 'accepted',
#     'bulk_created': False,
#     'task': 260729408,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93303667,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'p368an3DKQ',
#       'type': 'labels',
#       'value': {'end': 7,
#        'text': 'chinese',
#        'start': 0,
#        'labels': ['Cuisine']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'OAtgQV9RNZ',
#       'type': 'labels',
#       'value': {'end': 14,
#        'text': 'buffet',
#        'start': 8,
#        'labels': ['Amenity']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-13T02:38:05.754816Z',
#     'updated_at': '2026-04-13T02:38:05.754832Z',
#     'draft_created_at': '2026-04-13T02:37:57.447499Z',
#     'lead_time': 23.674,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '1ec57d83-6d73-4177-bd93-ce5b3c1e2684',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729408,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 100.0,
#   'data': {'text': 'chinese buffet style'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.072425Z',
#   'updated_at': '2026-04-13T02:45:09.263553Z',
#   'allow_skip': True,
#   'inner_id': 223,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': []},
#  {'id': 260729409,
#   'annotations': [{'id': 93301207,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': '-IxxzaOP-K',
#       'type': 'labels',
#       'value': {'end': 7,
#        'text': 'chinese',
#        'start': 0,
#        'labels': ['Cuisine']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'ACCEPTED',
#     'reviews': [{'id': 9299238,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-13T02:45:18.414218Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93301207,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102130056,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': '-IxxzaOP-K',
#         'type': 'labels',
#         'value': {'end': 7,
#          'text': 'chinese',
#          'start': 0,
#          'labels': ['Cuisine']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T23:39:32.067832Z',
#     'updated_at': '2026-04-12T23:39:32.067842Z',
#     'draft_created_at': None,
#     'lead_time': 21.627,
#     'prediction': {},
#     'result_count': 1,
#     'unique_id': '629c90ac-3b90-419b-85e0-2c0b434ebc7c',
#     'import_id': None,
#     'last_action': 'accepted',
#     'bulk_created': False,
#     'task': 260729409,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93303676,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': '1-y3oNMIfu',
#       'type': 'labels',
#       'value': {'end': 7,
#        'text': 'chinese',
#        'start': 0,
#        'labels': ['Cuisine']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-13T02:38:32.106750Z',
#     'updated_at': '2026-04-13T02:38:32.106760Z',
#     'draft_created_at': None,
#     'lead_time': 9.808,
#     'prediction': {},
#     'result_count': 1,
#     'unique_id': 'd9997ccd-1af8-4bdc-9b0e-d11947bece1b',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729409,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 100.0,
#   'data': {'text': 'chinese food joint'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.072456Z',
#   'updated_at': '2026-04-13T02:45:18.612523Z',
#   'allow_skip': True,
#   'inner_id': 224,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': []},
#  {'id': 260729410,
#   'annotations': [{'id': 93301208,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'BX6h6MdXIr',
#       'type': 'labels',
#       'value': {'end': 7,
#        'text': 'chinese',
#        'start': 0,
#        'labels': ['Cuisine']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'ACCEPTED',
#     'reviews': [{'id': 9299274,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-13T02:53:45.395914Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93301208,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102130057,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': 'BX6h6MdXIr',
#         'type': 'labels',
#         'value': {'end': 7,
#          'text': 'chinese',
#          'start': 0,
#          'labels': ['Cuisine']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T23:39:39.247014Z',
#     'updated_at': '2026-04-12T23:39:39.247026Z',
#     'draft_created_at': None,
#     'lead_time': 6.236,
#     'prediction': {},
#     'result_count': 1,
#     'unique_id': '80a1f323-5854-447b-b76e-3f5057e0a93d',
#     'import_id': None,
#     'last_action': 'accepted',
#     'bulk_created': False,
#     'task': 260729410,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93304236,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'zQ7r5Tjxox',
#       'type': 'labels',
#       'value': {'end': 7,
#        'text': 'chinese',
#        'start': 0,
#        'labels': ['Cuisine']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-13T02:53:39.384365Z',
#     'updated_at': '2026-04-13T02:53:39.384376Z',
#     'draft_created_at': None,
#     'lead_time': 5.142,
#     'prediction': {},
#     'result_count': 1,
#     'unique_id': '80de4c53-3fe5-4d9c-8079-1c6106dd96c1',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729410,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 100.0,
#   'data': {'text': 'chinese foooooood'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.072487Z',
#   'updated_at': '2026-04-13T02:53:45.577961Z',
#   'allow_skip': True,
#   'inner_id': 225,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': []},
#  {'id': 260729411,
#   'annotations': [{'id': 93301209,
#     'completed_by': {'id': 152637,
#      'email': 'bacosta3@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'gij0AO6oK7',
#       'type': 'labels',
#       'value': {'end': 7,
#        'text': 'chinese',
#        'start': 0,
#        'labels': ['Cuisine']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'N4YQ902GNb',
#       'type': 'labels',
#       'value': {'end': 19,
#        'text': 'japanese',
#        'start': 11,
#        'labels': ['Cuisine']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'ACCEPTED',
#     'reviews': [{'id': 9299272,
#       'created_by': {'id': 149661,
#        'email': 'ysasson@lion.lmu.edu',
#        'first_name': '',
#        'last_name': ''},
#       'created_at': '2026-04-13T02:53:20.851115Z',
#       'accepted': True,
#       'state': 'ACCEPTED',
#       'result': None,
#       'annotation': 93301209,
#       'fixed_annotation_history': None,
#       'previous_annotation_history': 102130058,
#       'last_annotation_history': None,
#       'remove_from_queue': None,
#       'started_at': None,
#       'previous_annotation_history_result': [{'id': 'gij0AO6oK7',
#         'type': 'labels',
#         'value': {'end': 7,
#          'text': 'chinese',
#          'start': 0,
#          'labels': ['Cuisine']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'},
#        {'id': 'N4YQ902GNb',
#         'type': 'labels',
#         'value': {'end': 19,
#          'text': 'japanese',
#          'start': 11,
#          'labels': ['Cuisine']},
#         'origin': 'manual',
#         'to_name': 'text',
#         'from_name': 'label'}]}],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-12T23:39:47.350061Z',
#     'updated_at': '2026-04-12T23:39:47.350071Z',
#     'draft_created_at': None,
#     'lead_time': 7.068,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': 'e32fb6c9-2597-4a85-ac29-ddac804b0041',
#     'import_id': None,
#     'last_action': 'accepted',
#     'bulk_created': False,
#     'task': 260729411,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661},
#    {'id': 93304212,
#     'completed_by': {'id': 149661,
#      'email': 'ysasson@lion.lmu.edu',
#      'first_name': '',
#      'last_name': ''},
#     'result': [{'id': 'Zvi1SOAYkX',
#       'type': 'labels',
#       'value': {'end': 7,
#        'text': 'chinese',
#        'start': 0,
#        'labels': ['Cuisine']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'},
#      {'id': 'VuGtMG5kgX',
#       'type': 'labels',
#       'value': {'end': 19,
#        'text': 'japanese',
#        'start': 11,
#        'labels': ['Cuisine']},
#       'origin': 'manual',
#       'to_name': 'text',
#       'from_name': 'label'}],
#     'state': 'CREATED',
#     'reviews': [],
#     'was_cancelled': False,
#     'ground_truth': False,
#     'created_at': '2026-04-13T02:53:14.806008Z',
#     'updated_at': '2026-04-13T02:53:14.806021Z',
#     'draft_created_at': None,
#     'lead_time': 12.016,
#     'prediction': {},
#     'result_count': 2,
#     'unique_id': '3a14f69c-4aa6-4043-b244-8e3ca1e180dd',
#     'import_id': None,
#     'last_action': 'submitted',
#     'bulk_created': False,
#     'task': 260729411,
#     'project': 250509,
#     'updated_by': 149661,
#     'parent_prediction': None,
#     'parent_annotation': None,
#     'last_created_by': 149661}],
#   'drafts': [],
#   'predictions': [],
#   'state': 'COMPLETED',
#   'agreement': 100.0,
#   'data': {'text': 'chinese or japanese restaurant'},
#   'meta': {},
#   'created_at': '2026-04-08T23:46:55.072518Z',
#   'updated_at': '2026-04-13T02:53:21.054247Z',
#   'allow_skip': True,
#   'inner_id': 226,
#   'total_annotations': 2,
#   'cancelled_annotations': 0,
#   'total_predictions': 0,
#   'comment_count': 0,
#   'unresolved_comment_count': 0,
#   'last_comment_updated_at': None,
#   'project': 250509,
#   'updated_by': 149661,
#   'comment_authors': []}]

# %%
# ============================================================
# SETUP: Install and import spaCy
# ============================================================
# spaCy is pre-installed in Colab. If running locally:
# !pip install spacy
# !python -m spacy download en_core_web_sm

import spacy
from spacy import displacy

# Load the small English model
# This model was trained on web text (blogs, news, comments)
# It recognizes entities like PERSON, ORG, GPE, DATE, MONEY, etc.
nlp = spacy.load("en_core_web_sm")

print(f"Model loaded: {nlp.meta['name']}")
print(f"Pipeline components: {nlp.pipe_names}")
# Out:
# Model loaded: core_web_sm
# Pipeline components: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
text_list=[]
for task in tasks:
    text = task["data"]["text"]
    text_list.append(text)

# %%
# ============================================================
# BASIC NER: Process a single sentence
# ============================================================
# nlp() processes text and returns a Doc object with all annotations

text='can you find me the closed burger king'

doc = nlp(text)

# Loop through detected entities
# Each entity has:
#   .text       → the actual text span (e.g., "Thomas Jefferson")
#   .start_char → character position where entity starts
#   .end_char   → character position where entity ends
#   .label_     → entity type label (e.g., "PERSON")

print(f"Text: {text}")
print(f"{'Entity':<30} {'Start':>5} {'End':>5}  {'Label'}")
print("-" * 60)
for ent in doc.ents:
    print(f"{ent.text:<30} {ent.start_char:>5} {ent.end_char:>5}  {ent.label_}")
# Out:
# Text: can you find me the closed burger king
# Entity                         Start   End  Label
# ------------------------------------------------------------

# %%
# ============================================================
# BASIC NER: Process a single sentence
# ============================================================
# nlp() processes text and returns a Doc object with all annotations

for text in text_list:
    doc = nlp(text)
    
    # Loop through detected entities
    # Each entity has:
    #   .text       → the actual text span (e.g., "Thomas Jefferson")
    #   .start_char → character position where entity starts
    #   .end_char   → character position where entity ends
    #   .label_     → entity type label (e.g., "PERSON")
    
    print(f"Text: {text}")
    print(f"{'Entity':<30} {'Start':>5} {'End':>5}  {'Label'}")
    print("-" * 60)
    for ent in doc.ents:
        print(f"{ent.text:<30} {ent.start_char:>5} {ent.end_char:>5}  {ent.label_}")
# Out:
# Text: can you find me the closed burger king
# Entity                         Start   End  Label
# ------------------------------------------------------------
# Text: can you find me the closest cheesecake factory
# Entity                         Start   End  Label
# ------------------------------------------------------------
# Text: can you find me the closet mc donalds
# Entity                         Start   End  Label
# ------------------------------------------------------------
# Text: can you find me the coast line grill nearby with seating at the bar
# Entity                         Start   End  Label
# ------------------------------------------------------------
# Text: can you find me the location of daisy gs it has hotel dining
# Entity                         Start   End  Label
# ------------------------------------------------------------
# Text: can you find me the nearest mcdonalds
# Entity                         Start   End  Label
# ------------------------------------------------------------
# Text: can you find me the nearest pizzeria
# Entity                         Start   End  Label
# ------------------------------------------------------------
# Text: can you find me the nicest restaurant for italian food
# Entity                         Start   End  Label
# ------------------------------------------------------------
# italian                           42    49  NORP
# Text: can you find me the phone number for ihop on tilburg street
# Entity                         Start   End  Label
# ------------------------------------------------------------
# Text: can you find me the restaurant with the best reviews
# Entity                         Start   End  Label
# ------------------------------------------------------------
# Text: check for cheap vegan diners in the theater district
# Entity                         Start   End  Label
# ------------------------------------------------------------
# Text: check to see if i can get a reservation now at that place you booked me last wednesday
# Entity                         Start   End  Label
# ------------------------------------------------------------
# last wednesday                    72    86  DATE
# Text: check whether there are any restaurants where pets are allowed
# Entity                         Start   End  Label
# ------------------------------------------------------------
# Text: chilis
# Entity                         Start   End  Label
# ------------------------------------------------------------
# chilis                             0     6  PERSON
# Text: chinese
# Entity                         Start   End  Label
# ------------------------------------------------------------
# chinese                            0     7  NORP
# Text: chinese buffet reviews
# Entity                         Start   End  Label
# ------------------------------------------------------------
# chinese                            0     7  NORP
# Text: chinese buffet style
# Entity                         Start   End  Label
# ------------------------------------------------------------
# chinese                            0     7  NORP
# Text: chinese food joint
# Entity                         Start   End  Label
# ------------------------------------------------------------
# chinese                            0     7  NORP
# Text: chinese foooooood
# Entity                         Start   End  Label
# ------------------------------------------------------------
# chinese                            0     7  NORP
# Text: chinese or japanese restaurant
# Entity                         Start   End  Label
# ------------------------------------------------------------
# chinese                            0     7  NORP
# japanese                          11    19  NORP

# %%
for text in text_list:
    doc = nlp(text)
    print(f"\nText: {text}")

    # Render the entity visualization
    displacy.render(doc, style="ent", jupyter=True, options={'distance': 120})

    # Also print entities in structured format
    for ent in doc.ents:
        print(f"  → {ent.text:<25} {ent.label_:<10} ({ent.start_char}-{ent.end_char})")

    if not doc.ents:
        print("  → No entities detected!")
# Out:
# Text: can you find me the closed burger king
# C:\Users\ysass\anaconda3\Lib\site-packages\spacy\displacy\__init__.py:215: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">can you find me the closed burger king</div></span>
#   → No entities detected!
#
# Text: can you find me the closest cheesecake factory
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">can you find me the closest cheesecake factory</div></span>
#   → No entities detected!
#
# Text: can you find me the closet mc donalds
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">can you find me the closet mc donalds</div></span>
#   → No entities detected!
#
# Text: can you find me the coast line grill nearby with seating at the bar
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">can you find me the coast line grill nearby with seating at the bar</div></span>
#   → No entities detected!
#
# Text: can you find me the location of daisy gs it has hotel dining
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">can you find me the location of daisy gs it has hotel dining</div></span>
#   → No entities detected!
#
# Text: can you find me the nearest mcdonalds
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">can you find me the nearest mcdonalds</div></span>
#   → No entities detected!
#
# Text: can you find me the nearest pizzeria
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">can you find me the nearest pizzeria</div></span>
#   → No entities detected!
#
# Text: can you find me the nicest restaurant for italian food
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">can you find me the nicest restaurant for
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     italian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  food</div></span>
#   → italian                   NORP       (42-49)
#
# Text: can you find me the phone number for ihop on tilburg street
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">can you find me the phone number for ihop on tilburg street</div></span>
#   → No entities detected!
#
# Text: can you find me the restaurant with the best reviews
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">can you find me the restaurant with the best reviews</div></span>
#   → No entities detected!
#
# Text: check for cheap vegan diners in the theater district
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">check for cheap vegan diners in the theater district</div></span>
#   → No entities detected!
#
# Text: check to see if i can get a reservation now at that place you booked me last wednesday
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">check to see if i can get a reservation now at that place you booked me
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div></span>
#   → last wednesday            DATE       (72-86)
#
# Text: check whether there are any restaurants where pets are allowed
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">check whether there are any restaurants where pets are allowed</div></span>
#   → No entities detected!
#
# Text: chilis
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chilis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div></span>
#   → chilis                    PERSON     (0-6)
#
# Text: chinese
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# </div></span>
#   → chinese                   NORP       (0-7)
#
# Text: chinese buffet reviews
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  buffet reviews</div></span>
#   → chinese                   NORP       (0-7)
#
# Text: chinese buffet style
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  buffet style</div></span>
#   → chinese                   NORP       (0-7)
#
# Text: chinese food joint
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  food joint</div></span>
#   → chinese                   NORP       (0-7)
#
# Text: chinese foooooood
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  foooooood</div></span>
#   → chinese                   NORP       (0-7)
#
# Text: chinese or japanese restaurant
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  or
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     japanese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  restaurant</div></span>
#   → chinese                   NORP       (0-7)
#   → japanese                  NORP       (11-19)
